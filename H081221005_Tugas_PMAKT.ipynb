# %% [markdown]
# <a href="https://colab.research.google.com/github/Patrickgian/PMAKT22_H081221005/blob/main/H081221005_Tugas_PMAKT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PATRICK GIAN YUNARTA T
# H081221005
# AKTUARIA

# %%
import pandas as pd

# %%
dataset = '/content/police_project.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
data.head(6)
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
# 5  2005-03-23     09:45          NaN             M          1982.0
#
#    driver_age driver_race                   violation_raw  violation  \
# 0        20.0       White                        Speeding   Speeding
# 1        40.0       White                        Speeding   Speeding
# 2        33.0       White                        Speeding   Speeding
# 3        19.0       White                Call for Service      Other
# 4        21.0       White                        Speeding   Speeding
# 5        23.0       Black  Equipment/Inspection Violation  Equipment
#
# ...

# %%
print(data.dtypes)
# Out:
# stop_date              object
# stop_time              object
# county_name           float64
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted         bool
# search_type            object
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# drugs_related_stop       bool
# dtype: object

# %%
datanoid = data.drop(data.columns[1],axis=1)

# %%
datanoid
# Out:
#         stop_date  county_name driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02          NaN             M          1985.0        20.0
# 1      2005-01-18          NaN             M          1965.0        40.0
# 2      2005-01-23          NaN             M          1972.0        33.0
# 3      2005-02-20          NaN             M          1986.0        19.0
# 4      2005-03-14          NaN             F          1984.0        21.0
# ...           ...          ...           ...             ...         ...
# 91736  2015-12-31          NaN             M          1986.0        29.0
# 91737  2015-12-31          NaN             F          1982.0        33.0
# 91738  2015-12-31          NaN             M          1992.0        23.0
# 91739  2015-12-31          NaN             M          1993.0        22.0
# 91740  2015-12-31          NaN             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
data.describe()
# Out:
#        county_name  driver_age_raw    driver_age
# count          0.0    86414.000000  86120.000000
# mean           NaN     1970.491228     34.011333
# std            NaN      110.914909     12.738564
# min            NaN        0.000000     15.000000
# 25%            NaN     1967.000000     23.000000
# 50%            NaN     1980.000000     31.000000
# 75%            NaN     1987.000000     43.000000
# max            NaN     8801.000000     99.000000

# %%
data.loc[:,"driver_age_raw":].corr()
# Out:
# <ipython-input-12-00300a68abb8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[:,"driver_age_raw":].corr()
#                     driver_age_raw  driver_age  search_conducted  \
# driver_age_raw            1.000000   -0.972431          0.014292
# driver_age               -0.972431    1.000000         -0.051621
# search_conducted          0.014292   -0.051621          1.000000
# drugs_related_stop        0.010809   -0.044920          0.498326
#
#                     drugs_related_stop
# driver_age_raw                0.010809
# driver_age                   -0.044920
# search_conducted              0.498326
# drugs_related_stop            1.000000

# %%
# @title driver_age_raw vs driver_age

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='driver_age_raw', y='driver_age', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets list -s "goal stanford"
# Out:
# ...
# ref                                                                     title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# faressayah/stanford-open-policing-project                               Stanford Open Policing Project                     772KB  2019-10-06 19:33:24           1586         44  0.9411765
# stanford-open-policing/stanford-open-policing-project-california        Stanford Open Policing Project - California        123MB  2017-07-10 20:41:07            591         19  0.875
# gowrishankarp/newspaper-text-summarization-cnn-dailymail                  CNN-DailyMail News Text Summarization            503MB  2021-10-23 20:17:48          11286        113  1.0
# ...

# %%
# !kaggle datasets download faressayah/stanford-open-policing-project
# Out:
# ...
#   0% 0.00/772k [00:00<?, ?B/s]
# 100% 772k/772k [00:00<00:00, 104MB/s]

# %%
# !unzip /content/stanford-open-policing-project.zip
# Out:
# Archive:  /content/stanford-open-policing-project.zip
# replace police_project.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: police_project.csv

# %%
pd.read_csv('/content/police_project.csv')
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...
